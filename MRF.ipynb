# %%
from MRF import *
import pandas as pd

# %%
data_in = pd.read_csv("/Users/ryanlucas/Desktop/MRF/MRF_data.csv")

# %%
mrf_output = MacroRandomForest(data=data_in,y_pos=0,x_pos=np.arange(1,4), oos_pos=np.arange(151,201),trend_push=4,quantile_rate=0.3)
# Out:
# Tree 1 out of 50
# 1 and 6
# 1 and 9
# 1 and 12
# 1 and 15
# 1 and 19
# 1 and 22
# 1 and 25
# 1 and 28
# 1 and 32
# 1 and 35
# 1 and 38
# 1 and 41
# 1 and 45
# 1 and 48
# 1 and 51
# 1 and 55
# 1 and 58
# 1 and 61
# 1 and 64
# 1 and 68
# 1 and 71
# 1 and 74
# 1 and 77
# 1 and 81
# 1 and 84
# 1 and 87
# 1 and 90
# 1 and 94
# 1 and 97
# 1 and 100
# 1 and 104
# 23.141739750838926
# 1 and 6
# 1 and 9
# 1 and 12
# 1 and 15
# 1 and 19
# 1 and 22
# 1 and 25
# 1 and 28
# 1 and 32
# 1 and 35
# 1 and 38
# 1 and 41
# 1 and 45
# 1 and 48
# 1 and 51
# 1 and 55
# 1 and 58
# 1 and 61
# 1 and 64
# 1 and 68
# 1 and 71
# 1 and 74
# 1 and 77
# 1 and 81
# 1 and 84
# 1 and 87
# 1 and 90
# 1 and 94
# 1 and 97
# 1 and 100
# 1 and 104
# 21.97312674992523
# 1 and 6
# 1 and 9
# 1 and 12
# 1 and 15
# 1 and 19
# 1 and 22
# 1 and 25
# 1 and 28
# 1 and 32
# 1 and 35
# 1 and 38
# 1 and 41
# 1 and 45
# 1 and 48
# 1 and 51
# 1 and 55
# 1 and 58
# 1 and 61
# 1 and 64
# 1 and 68
# 1 and 71
# 1 and 74
# 1 and 77
# 1 and 81
# 1 and 84
# 1 and 87
# 1 and 90
# 1 and 94
# 1 and 97
# 1 and 100
# 1 and 104
# 23.09997306907969
# 1 and 6
# 1 and 9
# 1 and 12
# 1 and 15
# 1 and 19
# 1 and 22
# 1 and 25
# 1 and 28
# 1 and 32
# 1 and 35
# 1 and 38
# 1 and 41
# 1 and 45
# 1 and 48
# 1 and 51
# 1 and 55
# 1 and 58
# 1 and 61
# 1 and 64
# 1 and 68
# 1 and 71
# 1 and 74
# 1 and 77
# 1 and 81
# 1 and 84
# 1 and 87
# 1 and 90
# 1 and 94
# 1 and 97
# 1 and 100
# 1 and 104
# 14.998649106279242
# 1 and 6
# 1 and 9
# 1 and 12
# 1 and 15
# 1 and 19
# 1 and 22
# 1 and 25
# 1 and 28
# 1 and 32
# 1 and 35
# 1 and 38
# 1 and 41
# 1 and 45
# 1 and 48
# 1 and 51
# 1 and 55
# 1 and 58
# 1 and 61
# 1 and 64
# 1 and 68
# 1 and 71
# 1 and 74
# 1 and 77
# 1 and 81
# 1 and 84
# 1 and 87
# 1 and 90
# 1 and 94
# 1 and 97
# 1 and 100
# 1 and 104
# 22.146826754588467
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'sse'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-4bb26a04f46d> in <module>
# ----> 1 mrf_output = MacroRandomForest(data=data_in,y_pos=0,x_pos=np.arange(1,4), oos_pos=np.arange(151,201),trend_push=4,quantile_rate=0.3)
#
# ~/Desktop/MacroRandomForest/MRF.py in __init__(self, data, x_pos, oos_pos, y_pos, minsize, mtry_frac, min_leaf_frac_of_x, VI, ERT, quantile_rate, S_priority_vec, random_x, trend_push, howmany_random_x, howmany_keep_best_VI, cheap_look_at_GTVPs, prior_var, prior_mean, subsampling_rate, rw_regul, keep_forest, block_size, fast_rw, ridge_lambda, HRW, B, resampling_opt, print_b)
#      64
#      65         ######## TRAIN FOREST ###########
# ---> 66         self._ensemble_loop()
#      67
#      68     def _name_translations(self):
#
# ~/Desktop/MacroRandomForest/MRF.py in _ensemble_loop(self)
#     256                 self.z_pos_effective = self.z_pos
#     257
# --> 258             self.rt_output = self._one_MRF_tree()
#     259
#     260     def _process_subsampling_selection(self):
#
# ~/Desktop/MacroRandomForest/MRF.py in _one_MRF_tree(self)
#     454                     lambda x: self._splitter_mrf(x))
#     455
# --> 456                 self.stop_flag = splitting['sse'] == np.inf
#     457
#     458                 # self.tmp_splitter = splitting[0, :].argmin()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in __getitem__(self, key)
#     851
#     852         elif key_is_scalar:
# --> 853             return self._get_value(key)
#     854
#     855         if is_hashable(key):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#     959
#     960         # Similar to Index.get_value, but we do not fall back to positional
# --> 961         loc = self.index.get_loc(label)
#     962         return self.index._get_values_for_loc(self, loc, label)
#     963
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'sse'
