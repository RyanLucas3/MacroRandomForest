# %%
from MRF import *
import pandas as pd

# %%
data_in = pd.read_csv("/Users/ryanlucas/Desktop/MRF/MRF_data.csv")

# %%
mrf_output = MacroRandomForest(data=data_in,y_pos=0,x_pos=np.arange(1,4), oos_pos=np.arange(151,201),trend_push=4,quantile_rate=0.3)
# Out:
# Tree 1 out of 50
# ['[16] >= -0.9003744468944752', '[16] < -0.9003744468944752']
# /Users/ryanlucas/Desktop/MacroRandomForest/MRF.py:397: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   self.this_data = data[eval(
#            1         2         3         4         5         6         7   \
# 0   -0.823460  0.610662  0.226449  0.012781 -0.400214 -0.329284 -1.123699
# 1    0.753117 -1.232463 -0.061927  0.148501 -1.187746  1.191555  0.475505
# 2    0.978808 -0.272778 -0.614842 -0.292002 -0.040387  0.542014 -0.803820
# 3    0.838029 -1.699953 -0.468039 -0.626052  1.278398 -2.454235 -0.666826
# 4   -1.835607 -2.145446  1.660234  2.087175  0.023714 -0.733702  0.407427
# ..        ...       ...       ...       ...       ...       ...       ...
# 145  0.438733  0.328919 -0.739686  0.552986 -1.444327 -0.958111  0.954954
# 146  0.102352  2.169690 -0.912255  0.678751 -0.230939 -0.586700 -1.224562
# 147 -0.700118  0.927278 -1.040102  1.034003 -0.724371 -0.863568 -0.762455
# 148  0.949861  0.008758 -1.357858 -1.111734 -0.864231  2.651300 -0.903315
# 149 -0.334901 -0.128225 -0.786172 -0.647355  0.482357  0.603606 -0.296839
#
#            8         9         10        11        12        13        14  \
# 0   -1.333084  0.031265 -1.246230 -0.081827  0.363156  1.367919 -0.271009
# 1    1.349463 -0.165237  1.169816 -0.017577  1.835831  0.850648  2.327730
# 2   -0.843782  0.296640 -0.202013 -1.185671 -0.164183 -0.806845  2.143732
# 3    0.658268 -1.334285 -0.159167 -1.870648  0.191432 -0.010792 -0.632765
# 4    0.445014  2.025831  0.283656  0.083093 -0.921518 -0.921501 -0.071748
# ..        ...       ...       ...       ...       ...       ...       ...
# 145 -2.085657  0.456537  0.091969  0.895581  0.902505 -1.058766 -1.611803
# 146 -0.384186  0.866748  1.365459  0.233146 -0.199638 -0.165154  2.046643
# 147 -0.611149 -0.887343 -0.588358  0.474784  0.346163 -0.163019 -1.285614
# 148  1.146574 -0.261016 -0.890569 -0.139723  0.399039  1.463474 -0.063561
# 149 -0.513536  0.189872 -0.079472 -0.175632  0.905081  0.063413 -0.036084
#
#            15        16
# 0   -1.861396 -1.723412
# 1    0.607720 -1.706091
# 2    0.471403 -1.688771
# 3   -0.208835 -1.671450
# 4    1.870754 -1.654129
# ..        ...       ...
# 145 -0.126207  0.788093
# 146  0.157250  0.805414
# 147 -0.827487  0.822734
# 148  0.023373  0.840055
# 149 -1.562693  0.857376
#
# [111 rows x 16 columns]
# ['[9] >= 0.29697141176186703', '[9] < 0.29697141176186703']
# /Users/ryanlucas/Desktop/MacroRandomForest/MRF.py:397: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   self.this_data = data[eval(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-4bb26a04f46d> in <module>
# ----> 1 mrf_output = MacroRandomForest(data=data_in,y_pos=0,x_pos=np.arange(1,4), oos_pos=np.arange(151,201),trend_push=4,quantile_rate=0.3)
#
# ~/Desktop/MacroRandomForest/MRF.py in __init__(self, data, x_pos, oos_pos, y_pos, minsize, mtry_frac, min_leaf_frac_of_x, VI, ERT, quantile_rate, S_priority_vec, random_x, trend_push, howmany_random_x, howmany_keep_best_VI, cheap_look_at_GTVPs, prior_var, prior_mean, subsampling_rate, rw_regul, keep_forest, block_size, fast_rw, ridge_lambda, HRW, B, resampling_opt, print_b)
#      66
#      67         ######## TRAIN FOREST ###########
# ---> 68         self._ensemble_loop()
#      69
#      70     def _name_translations(self):
#
# ~/Desktop/MacroRandomForest/MRF.py in _ensemble_loop(self)
#     258                 self.z_pos_effective = self.z_pos
#     259
# --> 260             self.rt_output = self._one_MRF_tree()
#     261
#     262     def _process_subsampling_selection(self):
#
# ~/Desktop/MacroRandomForest/MRF.py in _one_MRF_tree(self)
#     400                     self.column_binded_data = data
#     401
# --> 402                     self.column_binded_data.insert(
#     403                         0, "rando_vec", self.rando_vec)
#     404
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    3761         self._ensure_valid_index(value)
#    3762         value = self._sanitize_column(column, value, broadcast=False)
# -> 3763         self._mgr.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3764
#    3765     def assign(self, **kwargs) -> DataFrame:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in insert(self, loc, item, value, allow_duplicates)
#    1189         if not allow_duplicates and item in self.items:
#    1190             # Should this be a different kind of error??
# -> 1191             raise ValueError(f"cannot insert {item}, already exists")
#    1192
#    1193         if not isinstance(loc, int):
#
# ValueError: cannot insert rando_vec, already exists

# %%
test_df = pd.DataFrame([1,2,3,4,6])

# %%
test_df[test_df[0] > 3]
